# %% [markdown]
# # Teste Script BQ

# %% [markdown]
# # Imports

# %%
#import pandas as pd
#import requests
import zipfile
import io
import os
import re

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'credentials.json'
#C:\RMG\GBOTI\GIT\teste-vscode\credentialsrmgvs.json

# %%
from google.cloud import bigquery

# Conecte-se ao BigQuery especificando o projeto
client = bigquery.Client(project="ssbx-dataeng-ecomm-mono")  # Define o projeto aqui

print(client)

# %%
from google.cloud import bigquery

# Conecte-se ao BigQuery especificando o projeto
client = bigquery.Client(project="ssbx-dataeng-ecomm-mono")  # Define o projeto aqui

# Defina labels
'''
query_job_config = bigquery.QueryJobConfig(
   query_parameters=[],
   labels={
       "id_coordenacao": "cd39", # Define o id da coordenacao
       "id_iniciativa": "inic706", # Define o id da iniciativa
       "id_vs_chapter": "vsch03" # Define o id do chapter
   },
   use_legacy_sql=False,
)'''

query = '''select * from (select 1, '1-BQ-VScode' union all select 2, '2-BQ-VScode') '''
print (query)

# Define a consulta
query_job = client.query(query)
#   job_config=query_job_config,


# Execute a consulta e aguarde o resultado
print(query_job.result())
# Out:
# select * from (select 1, '1-BQ-VScode' union all select 2, '2-BQ-VScode')
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# Cell In[7], line 22
#      19 print (query)
#      21 # Define a consulta
# ---> 22 query_job = client.query(query)
#      23 #   job_config=query_job_config,
#      24
#      25
#      26 # Execute a consulta e aguarde o resultado
#      27 print(query_job.result())
#
# File c:\Users\rogeriomg\AppData\Local\Programs\Python\Python310\lib\site-packages\google\cloud\bigquery\client.py:3492, in Client.query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method)
#    3481     return _job_helpers.query_jobs_query(
#    3482         self,
#    3483         query,
#    (...)
#    3489         job_retry,
#    3490     )
#    3491 elif api_method == enums.QueryApiMethod.INSERT:
# ...

# %% [markdown]
# # Request

# %% [markdown]
# # Iteracao
